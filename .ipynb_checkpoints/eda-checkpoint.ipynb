# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data_cleanig_03_June_2022_II.csv')

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Rating', 'Company', 'Description',
#        'Location', 'size', 'type', 'sector', 'founded', 'industry', 'revenue',
#        'Per Hour', 'Employ Prov', 'Min Salary', 'Max Salary', 'Avg Salary',
#        'age', 'python_req', 'matlab_req', 'spark_req', 'sql_req', 'job_simp'],
#       dtype='object')

# %%
df.describe()
# Out:
#            Rating    Per Hour  Employ Prov  Min Salary  Max Salary  \
# count  892.000000  892.000000   892.000000  892.000000  892.000000
# mean     3.659753    0.039238     0.262332   80.748879  136.760090
# std      1.413970    0.194269     0.440149   22.355854   40.085468
# min     -1.000000    0.000000     0.000000   20.000000   20.000000
# 25%      3.600000    0.000000     0.000000   64.000000  115.000000
# 50%      4.000000    0.000000     0.000000   73.000000  129.000000
# 75%      4.400000    0.000000     1.000000  100.000000  167.000000
# max      5.000000    1.000000     1.000000  150.000000  241.000000
#
#        Avg Salary          age  python_req  matlab_req   spark_req     sql_req
# count  892.000000   741.000000  892.000000  892.000000  892.000000  892.000000
# mean   108.754484   220.300945    0.790359    0.107623    0.251121    0.653587
# std     29.033075   552.334197    0.407281    0.310078    0.433901    0.476093
# ...

# %%
df['Rating'].hist()
# Out:
# <AxesSubplot:>

# %%
df['Avg Salary'].hist()
# Out:
# <AxesSubplot:>

# %%
df['age'].value_counts()
# Out:
# 6.0       68
# 2023.0    63
# 28.0      46
# 9.0       43
# 20.0      42
#           ..
# 118.0      1
# 10.0       1
# 24.0       1
# 67.0       1
# 234.0      1
# Name: age, Length: 66, dtype: int64

# %%
df['age'].hist()
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column = 'Avg Salary')
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column = 'Rating')
# Out:
# <AxesSubplot:>

# %%
df.boxplot(column = 'age')
# Out:
# <AxesSubplot:>

# %%
df[['age','Avg Salary','Rating']].corr()
# Out:
#                  age  Avg Salary    Rating
# age         1.000000   -0.303442 -0.945684
# Avg Salary -0.303442    1.000000  0.248721
# Rating     -0.945684    0.248721  1.000000

# %%
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(df[['age','Avg Salary','Rating']].corr(),vmax=.3, center=0, cmap=cmap,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Rating', 'Company', 'Description',
#        'Location', 'size', 'type', 'sector', 'founded', 'industry', 'revenue',
#        'Per Hour', 'Employ Prov', 'Min Salary', 'Max Salary', 'Avg Salary',
#        'age', 'python_req', 'matlab_req', 'spark_req', 'sql_req', 'job_simp'],
#       dtype='object')

# %%
df_cate = df[['Location','size','industry', 'revenue', 'python_req', 'matlab_req', 'spark_req', 'sql_req', 'job_simp', 'Company', 'type', 'sector']]

# %%
for i in df_cate.columns:
    cat_num = df_cate[i].value_counts()
    print("graph for %s with total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Location with total = 9
# graph for size with total = 9
# graph for industry with total = 42
# graph for revenue with total = 13
# graph for python_req with total = 2
# graph for matlab_req with total = 2
# graph for spark_req with total = 2
# graph for sql_req with total = 2
# graph for job_simp with total = 3
# graph for Company with total = 135
# graph for type with total = 18
# graph for sector with total = 25

# %%
for i in df_cate[['industry','Company']].columns:
    cat_num = df_cate[i].value_counts()[:20]
    print("graph for %s top %d" % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for industry top 20
# graph for Company top 20

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Rating', 'Company', 'Description',
#        'Location', 'size', 'type', 'sector', 'founded', 'industry', 'revenue',
#        'Per Hour', 'Employ Prov', 'Min Salary', 'Max Salary', 'Avg Salary',
#        'age', 'python_req', 'matlab_req', 'spark_req', 'sql_req', 'job_simp'],
#       dtype='object')

# %%
pd.pivot_table(df, index = 'job_simp', values = 'Avg Salary').sort_values('job_simp', ascending = False)
# Out:
#                 Avg Salary
# job_simp
# mle             120.411765
# data scientist  110.246257
# analyst          82.505319

# %%
pd.pivot_table(df, index = ['Location','job_simp'], values = 'Avg Salary').sort_values('Location', ascending = False)
# Out:
#                                   Avg Salary
# Location          job_simp
# United States     mle             124.166667
#                   data scientist  110.193750
#                   analyst          89.750000
# Seattle, WA       data scientist  111.047009
#                   analyst          79.500000
# San Jose, CA      mle             111.875000
#                   data scientist  111.555556
#                   analyst          87.791667
# Remote            mle             143.750000
#                   data scientist  117.333333
#                   analyst          80.687500
# New York, NY      mle             127.166667
#                   data scientist   96.461538
#                   analyst          95.666667
# Mountain View, CA mle             117.500000
#                   data scientist  106.807692
#                   analyst          90.800000
# Illinois          data scientist  111.434783
#                   analyst          73.000000
# ...

# %%
pd.pivot_table(df[df.job_simp == 'data scientist'], index = 'Location', values = 'Avg Salary').sort_values('Avg Salary', ascending = False)
# Out:
#                    Avg Salary
# Location
# Baton Rouge, LA    130.250000
# Remote             117.333333
# San Jose, CA       111.555556
# Illinois           111.434783
# Seattle, WA        111.047009
# Calabasas, CA      110.370370
# United States      110.193750
# Mountain View, CA  106.807692
# New York, NY        96.461538

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Rating', 'Company', 'Description',
#        'Location', 'size', 'type', 'sector', 'founded', 'industry', 'revenue',
#        'Per Hour', 'Employ Prov', 'Min Salary', 'Max Salary', 'Avg Salary',
#        'age', 'python_req', 'matlab_req', 'spark_req', 'sql_req', 'job_simp'],
#       dtype='object')

# %%
df_pivots = df[['Rating', 'industry', 'sector','revenue', 'Employ Prov', 'python_req', 'matlab_req', 'spark_req', 'sql_req', 'Avg Salary']]

# %%
for i in df_pivots.columns:
#     print(i)
    print(pd.pivot_table(df_pivots,index = i, values = 'Avg Salary').sort_values('Avg Salary', ascending = False))
# Out:
#         Avg Salary
# Rating
#  4.7    149.585714
#  3.8    131.028302
#  4.3    116.750000
#  4.2    114.509434
#  3.3    114.204545
#  3.7    113.712500
#  4.1    113.152000
#  4.5    111.375000
#  3.9    109.718750
#  3.1    106.912281
#  4.8    105.262500
#  5.0    104.862745
#  3.6    104.178571
#  3.4    103.500000
#  4.0     97.855769
#  2.9     93.000000
#  4.6     91.016129
# -1.0     82.613636
#  3.5     78.136364
#  4.4     75.019231
#  3.0     42.000000
#                                              Avg Salary
# industry
# Computer Hardware Development                161.358696
# Construction, Repair & Maintenance Services  150.000000
# Wholesale                                    138.571429
# Investment & Asset Management                135.500000
# Information Technology                       133.741935
# Consumer Product Manufacturing               132.500000
# Internet & Web Services                      129.772222
# ...

# %%
pd.pivot_table(df_pivots, index = 'revenue', columns = 'python_req', values = 'Avg Salary', aggfunc = 'count')
# Out:
# python_req                           0      1
# revenue
# $1 to $2 billion (USD)            18.0   41.0
# $1 to $5 million (USD)             NaN    3.0
# $10 to $25 million (USD)           NaN    3.0
# $10+ billion (USD)                19.0  161.0
# $100 to $500 million (USD)        14.0    5.0
# $2 to $5 billion (USD)            44.0   32.0
# $25 to $50 million (USD)           2.0   28.0
# $5 to $10 billion (USD)            1.0   72.0
# $5 to $10 million (USD)            NaN    1.0
# $50 to $100 million (USD)          8.0   28.0
# $500 million to $1 billion (USD)   1.0    9.0
# -1                                29.0  186.0
# Unknown / Non-Applicable          51.0  136.0

# %%
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\TEGAR SATRIYA
# [nltk_data]     WIGUNA\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to C:\Users\TEGAR SATRIYA
# [nltk_data]     WIGUNA\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
words = " ".join(df['Description'])

def punctuation_stop(text):
    """remove punctuation and stop words"""
    filtered = []
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        if w not in stop_words and w.isalpha():
            filtered.append(w.lower())
    return filtered


words_filtered = punctuation_stop(words)

text = " ".join([ele for ele in words_filtered])

wc= WordCloud(background_color="white", random_state=1,stopwords=STOPWORDS, max_words = 2000, width =800, height = 1500)
wc.generate(text)

plt.figure(figsize=[10,10])
plt.imshow(wc,interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
df.to_csv('eda_data_04_June_2022_I.csv')
